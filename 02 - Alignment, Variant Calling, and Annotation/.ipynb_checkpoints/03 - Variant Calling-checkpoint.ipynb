# %% [markdown]
# # Variant Calling
#
# Now that we have the aligned sequences to the reference, we can look for difference between the aligned sequences and the reference. This process is also known as variant calling.
#
# Let's review the files that we have.

# %%
ls -lh
# Out:
# total 480M
# -rw-rw-r-- 1 jupyter jupyter  14K May 19 16:54 01 - Preparations for Finding a Disease Mutation.ipynb
# -rw-rw-r-- 1 jupyter jupyter  16K May 19 17:04 02 - Aligning the FASTQ File.ipynb
# -rw-rw-r-- 1 jupyter jupyter 5.4K May 19 11:12 03 - Variant Calling.ipynb
# -rw-rw-r-- 1 jupyter jupyter 4.8K May 19 11:12 04 - Annotation of Variants.ipynb
# -rw-r--r-- 1 jupyter jupyter 176M May 19 11:12 chr5.fa
# -rw-rw-r-- 1 jupyter jupyter  131 May 19 11:12 chr5.fa.amb
# -rw-rw-r-- 1 jupyter jupyter   43 May 19 11:12 chr5.fa.ann
# -rw-rw-r-- 1 jupyter jupyter 173M May 19 11:12 chr5.fa.bwt
# -rw-rw-r-- 1 jupyter jupyter   23 May 19 11:12 chr5.fa.fai
# -rw-rw-r-- 1 jupyter jupyter  44M May 19 11:12 chr5.fa.pac
# -rw-rw-r-- 1 jupyter jupyter  87M May 19 11:12 chr5.fa.sa
# -rw-r--r-- 1 jupyter jupyter 820K May 19 11:12 input.fq
# -rw-rw-r-- 1 jupyter jupyter  25K May 19 16:53 input.png
# -rw-rw-r-- 1 jupyter jupyter 6.0K May 19 16:53 input.qual
# -rw-rw-r-- 1 jupyter jupyter 963K May 19 17:00 mapped.sam

# %% [markdown]
# ## Preparing for variant calling
#
# In order to perform variant calling, we need to preprocess the SAM file as well as the reference chromosome 5 fasta file. The following steps will be performed :
#
# * Converting SAM to BAM format (this is the binary compressed version)
# * Sorting the BAM file
# * Indexing the BAM file
# * Indexing the reference fasta file

# %% [markdown]
# ### Processing the SAM file generated by BWA
#
# We will process the SAM file using samtools, which can be accessed after loading the module.

# %%
module load bio/samtools
samtools view
# Out:
# Usage:   samtools view [options] <in.bam>|<in.sam>|<in.cram> [region ...]
#
# Options: -b       output BAM
#          -C       output CRAM (requires -T)
#          -1       use fast BAM compression (implies -b)
#          -u       uncompressed BAM output (implies -b)
#          -h       include header in SAM output
#          -H       print SAM header only (no alignments)
#          -c       print only the count of matching records
#          -o FILE  output file name [stdout]
#          -U FILE  output reads not selected by filters to FILE [null]
#          -t FILE  FILE listing reference names and lengths (see long help) [null]
#          -T FILE  reference sequence FASTA FILE [null]
#          -L FILE  only include reads overlapping this BED FILE [null]
#          -r STR   only include reads in read group STR [null]
#          -R FILE  only include reads with read group listed in FILE [null]
#          -q INT   only include reads with mapping quality >= INT [0]
#          -l STR   only include reads in library STR [null]
#          -m INT   only include reads with number of CIGAR operations
#                   consuming query sequence >= INT [0]
#          -f INT   only include reads with all bits set in INT set in FLAG [0]
#          -F INT   only include reads with none of the bits set in INT
#                   set in FLAG [0]
#          -x STR   read tag to strip (repeatable) [null]
#          -B       collapse the backward CIGAR operation
#          -s FLOAT integer part sets seed of random number generator [0];
#                   rest sets fraction of templates to subsample [no subsampling]
#          -@ INT   number of BAM compression threads [0]
#          -?       print long help, including note about region specification
#          -S       ignored (input format is auto-detected)

# %% [markdown]
# We will begin by converting the SAM file to the compressed BAM format. To do this, we will need to refer to the reference fasta file and the SAM file. The output will be redirected to a new BAM file.

# %%
samtools view -bT chr5.fa mapped.sam > mapped.bam

# %%
ls -l
# Out:
# total 491496
# -rw-rw-r-- 1 jupyter jupyter     13805 May 19 16:54 01 - Preparations for Finding a Disease Mutation.ipynb
# -rw-rw-r-- 1 jupyter jupyter     15890 May 19 17:04 02 - Aligning the FASTQ File.ipynb
# -rw-rw-r-- 1 jupyter jupyter      9039 May 19 17:08 03 - Variant Calling.ipynb
# -rw-rw-r-- 1 jupyter jupyter      4877 May 19 11:12 04 - Annotation of Variants.ipynb
# -rw-r--r-- 1 jupyter jupyter 184533572 May 19 11:12 chr5.fa
# -rw-rw-r-- 1 jupyter jupyter       131 May 19 11:12 chr5.fa.amb
# -rw-rw-r-- 1 jupyter jupyter        43 May 19 11:12 chr5.fa.ann
# -rw-rw-r-- 1 jupyter jupyter 180915336 May 19 11:12 chr5.fa.bwt
# -rw-rw-r-- 1 jupyter jupyter        23 May 19 11:12 chr5.fa.fai
# -rw-rw-r-- 1 jupyter jupyter  45228817 May 19 11:12 chr5.fa.pac
# -rw-rw-r-- 1 jupyter jupyter  90457680 May 19 11:12 chr5.fa.sa
# -rw-r--r-- 1 jupyter jupyter    839362 May 19 11:12 input.fq
# -rw-rw-r-- 1 jupyter jupyter     25235 May 19 16:53 input.png
# -rw-rw-r-- 1 jupyter jupyter      6134 May 19 16:53 input.qual
# -rw-rw-r-- 1 jupyter jupyter    216886 May 19 17:08 mapped.bam
# -rw-rw-r-- 1 jupyter jupyter    985658 May 19 17:00 mapped.sam

# %% [markdown]
# Notice that the BAM files is much smaller than the SAM file

# %% [markdown]
# Next, we will sort and index the BAM file

# %%
samtools sort mapped.bam mapped.sort
samtools index mapped.sort.bam

# %%
ls -l
# Out:
# total 491780
# -rw-rw-r-- 1 jupyter jupyter     13805 May 19 16:54 01 - Preparations for Finding a Disease Mutation.ipynb
# -rw-rw-r-- 1 jupyter jupyter     15890 May 19 17:04 02 - Aligning the FASTQ File.ipynb
# -rw-rw-r-- 1 jupyter jupyter      9039 May 19 17:08 03 - Variant Calling.ipynb
# -rw-rw-r-- 1 jupyter jupyter      4877 May 19 11:12 04 - Annotation of Variants.ipynb
# -rw-r--r-- 1 jupyter jupyter 184533572 May 19 11:12 chr5.fa
# -rw-rw-r-- 1 jupyter jupyter       131 May 19 11:12 chr5.fa.amb
# -rw-rw-r-- 1 jupyter jupyter        43 May 19 11:12 chr5.fa.ann
# -rw-rw-r-- 1 jupyter jupyter 180915336 May 19 11:12 chr5.fa.bwt
# -rw-rw-r-- 1 jupyter jupyter        23 May 19 11:12 chr5.fa.fai
# -rw-rw-r-- 1 jupyter jupyter  45228817 May 19 11:12 chr5.fa.pac
# -rw-rw-r-- 1 jupyter jupyter  90457680 May 19 11:12 chr5.fa.sa
# -rw-r--r-- 1 jupyter jupyter    839362 May 19 11:12 input.fq
# -rw-rw-r-- 1 jupyter jupyter     25235 May 19 16:53 input.png
# -rw-rw-r-- 1 jupyter jupyter      6134 May 19 16:53 input.qual
# -rw-rw-r-- 1 jupyter jupyter    216886 May 19 17:08 mapped.bam
# -rw-rw-r-- 1 jupyter jupyter    985658 May 19 17:00 mapped.sam
# -rw-rw-r-- 1 jupyter jupyter    216866 May 19 17:09 mapped.sort.bam
# -rw-rw-r-- 1 jupyter jupyter     72808 May 19 17:09 mapped.sort.bam.bai

# %% [markdown]
# ### Indexing the reference fasta file
#
# To prepare the reference fasta file for variant calling, we need to index the file

# %%
module load bio/samtools
samtools faidx chr5.fa

# %%
ls -l
# Out:
# total 491780
# -rw-rw-r-- 1 jupyter jupyter     13805 May 19 16:54 01 - Preparations for Finding a Disease Mutation.ipynb
# -rw-rw-r-- 1 jupyter jupyter     15890 May 19 17:04 02 - Aligning the FASTQ File.ipynb
# -rw-rw-r-- 1 jupyter jupyter      9039 May 19 17:08 03 - Variant Calling.ipynb
# -rw-rw-r-- 1 jupyter jupyter      4877 May 19 11:12 04 - Annotation of Variants.ipynb
# -rw-r--r-- 1 jupyter jupyter 184533572 May 19 11:12 chr5.fa
# -rw-rw-r-- 1 jupyter jupyter       131 May 19 11:12 chr5.fa.amb
# -rw-rw-r-- 1 jupyter jupyter        43 May 19 11:12 chr5.fa.ann
# -rw-rw-r-- 1 jupyter jupyter 180915336 May 19 11:12 chr5.fa.bwt
# -rw-rw-r-- 1 jupyter jupyter        23 May 19 17:09 chr5.fa.fai
# -rw-rw-r-- 1 jupyter jupyter  45228817 May 19 11:12 chr5.fa.pac
# -rw-rw-r-- 1 jupyter jupyter  90457680 May 19 11:12 chr5.fa.sa
# -rw-r--r-- 1 jupyter jupyter    839362 May 19 11:12 input.fq
# -rw-rw-r-- 1 jupyter jupyter     25235 May 19 16:53 input.png
# -rw-rw-r-- 1 jupyter jupyter      6134 May 19 16:53 input.qual
# -rw-rw-r-- 1 jupyter jupyter    216886 May 19 17:08 mapped.bam
# -rw-rw-r-- 1 jupyter jupyter    985658 May 19 17:00 mapped.sam
# -rw-rw-r-- 1 jupyter jupyter    216866 May 19 17:09 mapped.sort.bam
# -rw-rw-r-- 1 jupyter jupyter     72808 May 19 17:09 mapped.sort.bam.bai

# %% [markdown]
# Notice the .fai file

# %%
head chr5.fa.fai
# Out:
# chr5	180915260	6	50	51

# %% [markdown]
# ## Variant calling using Platypus
#
# There are different methods for variant calling. Here, we will use Platypus, a haplotype-based variant caller that increases the sensitivity and specificity of the varianta calls (http://www.well.ox.ac.uk/platypus)
#
# <img src="https://bchdb.nus.edu.sg/media/notebook/ng.3036-F1.jpg" width=800></img>

# %%
module load bio/platypus
Platypus.py callVariants -h

# %% [markdown]
# The variant caller requires the reference file and the BAM file with its index.

# %%
Platypus.py callVariants --refFile=chr5.fa --bamFiles=mapped.sort.bam --assemble=1 --nCPU=8 -o result.vcf
# Out:
# 2017-05-19 18:49:04,914 - INFO - Beginning variant calling
# 2017-05-19 18:49:04,915 - INFO - Output will go to result.vcf
# 2017-05-19 18:49:04,928 - INFO - Processing region chr5:0-100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:04,929 - INFO - Processing region chr5:100000-200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:04,929 - INFO - Processing region chr5:200000-300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:04,930 - INFO - Processing region chr5:400000-500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:04,930 - INFO - Processing region chr5:300000-400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:04,931 - INFO - Processing region chr5:500000-600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:04,931 - INFO - Processing region chr5:600000-700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:04,932 - INFO - Processing region chr5:700000-800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,217 - INFO - Processing region chr5:8500000-8600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,233 - INFO - Processing region chr5:8700000-8800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,242 - INFO - Processing region chr5:8200000-8300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,251 - INFO - Processing region chr5:8100000-8200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,257 - INFO - Processing region chr5:8400000-8500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,273 - INFO - Processing region chr5:8000000-8100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,297 - INFO - Processing region chr5:8300000-8400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:06,313 - INFO - Processing region chr5:8600000-8700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,484 - INFO - Processing region chr5:16500000-16600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,521 - INFO - Processing region chr5:16700000-16800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,542 - INFO - Processing region chr5:16200000-16300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,562 - INFO - Processing region chr5:16100000-16200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,573 - INFO - Processing region chr5:16400000-16500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,611 - INFO - Processing region chr5:16600000-16700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,620 - INFO - Processing region chr5:16000000-16100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:07,641 - INFO - Processing region chr5:16300000-16400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,741 - INFO - Processing region chr5:24700000-24800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,784 - INFO - Processing region chr5:24500000-24600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,825 - INFO - Processing region chr5:24200000-24300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,857 - INFO - Processing region chr5:24400000-24500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,877 - INFO - Processing region chr5:24600000-24700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,915 - INFO - Processing region chr5:24300000-24400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,971 - INFO - Processing region chr5:24000000-24100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:08,986 - INFO - Processing region chr5:24100000-24200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,012 - INFO - Processing region chr5:32700000-32800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,119 - INFO - Processing region chr5:32500000-32600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,144 - INFO - Processing region chr5:32200000-32300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,145 - INFO - Processing region chr5:32600000-32700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,149 - INFO - Processing region chr5:32400000-32500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,213 - INFO - Processing region chr5:32300000-32400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,286 - INFO - Processing region chr5:32100000-32200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:10,308 - INFO - Processing region chr5:32000000-32100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,277 - INFO - Processing region chr5:40700000-40800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,384 - INFO - Processing region chr5:40500000-40600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,409 - INFO - Processing region chr5:40600000-40700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,436 - INFO - Processing region chr5:40200000-40300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,450 - INFO - Processing region chr5:40400000-40500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,507 - INFO - Processing region chr5:40300000-40400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,572 - INFO - Processing region chr5:40100000-40200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:11,839 - INFO - Processing region chr5:40000000-40100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,359 - INFO - Processing region chr5:48700000-48800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,474 - INFO - Processing region chr5:48500000-48600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,514 - INFO - Processing region chr5:48600000-48700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,548 - INFO - Processing region chr5:48200000-48300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,558 - INFO - Processing region chr5:48400000-48500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,624 - INFO - Processing region chr5:48300000-48400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,686 - INFO - Processing region chr5:48100000-48200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:12,983 - INFO - Processing region chr5:48000000-48100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:13,535 - INFO - Processing region chr5:56700000-56800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:13,564 - INFO - Processing region chr5:56500000-56600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:13,650 - INFO - Processing region chr5:56200000-56300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:13,666 - INFO - Processing region chr5:56600000-56700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:13,682 - INFO - Processing region chr5:56400000-56500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:13,728 - INFO - Processing region chr5:56300000-56400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:13,789 - INFO - Processing region chr5:56100000-56200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:14,122 - INFO - Processing region chr5:56000000-56100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:14,803 - INFO - Processing region chr5:64700000-64800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:14,831 - INFO - Processing region chr5:64500000-64600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:14,931 - INFO - Processing region chr5:64600000-64700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:14,964 - INFO - Processing region chr5:64200000-64300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:14,980 - INFO - Processing region chr5:64400000-64500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:15,030 - INFO - Processing region chr5:64300000-64400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:15,085 - INFO - Processing region chr5:64100000-64200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:15,449 - INFO - Processing region chr5:64000000-64100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,100 - INFO - Processing region chr5:72500000-72600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,127 - INFO - Processing region chr5:72700000-72800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,207 - INFO - Processing region chr5:72600000-72700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,250 - INFO - Processing region chr5:72200000-72300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,281 - INFO - Processing region chr5:72400000-72500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,333 - INFO - Processing region chr5:72300000-72400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,379 - INFO - Processing region chr5:72100000-72200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:16,774 - INFO - Processing region chr5:72000000-72100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:17,367 - INFO - Processing region chr5:80500000-80600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:17,398 - INFO - Processing region chr5:80700000-80800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:17,481 - INFO - Processing region chr5:80600000-80700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:17,562 - INFO - Processing region chr5:80200000-80300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:17,596 - INFO - Processing region chr5:80400000-80500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:17,625 - INFO - Processing region chr5:80300000-80400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:17,675 - INFO - Processing region chr5:80100000-80200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,096 - INFO - Processing region chr5:80000000-80100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,640 - INFO - Processing region chr5:88500000-88600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,666 - INFO - Processing region chr5:88700000-88800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,760 - INFO - Processing region chr5:88600000-88700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,851 - INFO - Processing region chr5:88200000-88300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,891 - INFO - Processing region chr5:88400000-88500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,922 - INFO - Processing region chr5:88300000-88400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:18,954 - INFO - Processing region chr5:88100000-88200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:19,426 - INFO - Processing region chr5:88000000-88100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:19,911 - INFO - Processing region chr5:96500000-96600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:19,932 - INFO - Processing region chr5:96700000-96800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:20,029 - INFO - Processing region chr5:96600000-96700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:20,136 - INFO - Processing region chr5:96400000-96500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:20,144 - INFO - Processing region chr5:96200000-96300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:20,224 - INFO - Processing region chr5:96300000-96400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:20,239 - INFO - Processing region chr5:96100000-96200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:20,753 - INFO - Processing region chr5:96000000-96100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:21,192 - INFO - Processing region chr5:104500000-104600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:21,202 - INFO - Processing region chr5:104700000-104800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:21,410 - INFO - Processing region chr5:104600000-104700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:21,444 - INFO - Processing region chr5:104400000-104500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:21,456 - INFO - Processing region chr5:104200000-104300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:21,517 - INFO - Processing region chr5:104300000-104400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:21,525 - INFO - Processing region chr5:104100000-104200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,082 - INFO - Processing region chr5:104000000-104100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,465 - INFO - Processing region chr5:112500000-112600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,480 - INFO - Processing region chr5:112700000-112800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,732 - INFO - Processing region chr5:112600000-112700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,745 - INFO - Processing region chr5:112200000-112300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,752 - INFO - Processing region chr5:112400000-112500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,796 - INFO - Processing region chr5:112300000-112400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:22,824 - INFO - Processing region chr5:112100000-112200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:23,410 - INFO - Processing region chr5:112000000-112100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:23,734 - INFO - Processing region chr5:120500000-120600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:23,761 - INFO - Processing region chr5:120700000-120800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:24,041 - INFO - Processing region chr5:120200000-120300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:24,043 - INFO - Processing region chr5:120600000-120700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:24,058 - INFO - Processing region chr5:120400000-120500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:24,080 - INFO - Processing region chr5:120300000-120400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:24,089 - INFO - Processing region chr5:120100000-120200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:24,734 - INFO - Processing region chr5:120000000-120100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:25,003 - INFO - Processing region chr5:128500000-128600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:25,027 - INFO - Processing region chr5:128700000-128800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:25,319 - INFO - Processing region chr5:128600000-128700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:25,340 - INFO - Processing region chr5:128200000-128300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:25,348 - INFO - Processing region chr5:128400000-128500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:25,368 - INFO - Processing region chr5:128100000-128200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:25,383 - INFO - Processing region chr5:128300000-128400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,062 - INFO - Processing region chr5:128000000-128100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,270 - INFO - Processing region chr5:136500000-136600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,293 - INFO - Processing region chr5:136700000-136800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,643 - INFO - Processing region chr5:136200000-136300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,658 - INFO - Processing region chr5:136400000-136500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,665 - INFO - Processing region chr5:136100000-136200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,692 - INFO - Processing region chr5:136300000-136400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:26,693 - INFO - Processing region chr5:136600000-136700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,384 - INFO - Processing region chr5:136000000-136100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,535 - INFO - Processing region chr5:144500000-144600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,555 - INFO - Processing region chr5:144700000-144800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,936 - INFO - Processing region chr5:144400000-144500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,954 - INFO - Processing region chr5:144600000-144700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,963 - INFO - Processing region chr5:144200000-144300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,974 - INFO - Processing region chr5:144100000-144200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:27,988 - INFO - Processing region chr5:144300000-144400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:28,702 - INFO - Processing region chr5:144000000-144100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:28,819 - INFO - Processing region chr5:152700000-152800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:28,842 - INFO - Processing region chr5:152500000-152600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:29,219 - INFO - Processing region chr5:152600000-152700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:29,256 - INFO - Processing region chr5:152200000-152300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:29,262 - INFO - Processing region chr5:152100000-152200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:29,269 - INFO - Processing region chr5:152400000-152500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:29,295 - INFO - Processing region chr5:152300000-152400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,027 - INFO - Processing region chr5:152000000-152100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,038 - INFO - Processing region chr5:160700000-160800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,164 - INFO - Processing region chr5:160500000-160600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,490 - INFO - Processing region chr5:160600000-160700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,536 - INFO - Processing region chr5:160400000-160500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,555 - INFO - Processing region chr5:160200000-160300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,560 - INFO - Processing region chr5:160300000-160400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:30,567 - INFO - Processing region chr5:160100000-160200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,305 - INFO - Processing region chr5:168700000-168800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,351 - INFO - Processing region chr5:160000000-160100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,493 - INFO - Processing region chr5:168500000-168600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,768 - INFO - Processing region chr5:168600000-168700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,805 - INFO - Processing region chr5:168400000-168500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,838 - INFO - Processing region chr5:168100000-168200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,840 - INFO - Processing region chr5:168200000-168300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:31,850 - INFO - Processing region chr5:168300000-168400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:32,575 - INFO - Processing region chr5:176700000-176800000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:32,675 - INFO - Processing region chr5:168000000-168100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:32,811 - INFO - Processing region chr5:176500000-176600000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:33,066 - INFO - Processing region chr5:176400000-176500000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:33,066 - INFO - Processing region chr5:176600000-176700000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:33,111 - INFO - Processing region chr5:176300000-176400000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:33,137 - INFO - Processing region chr5:176100000-176200000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:33,160 - INFO - Processing region chr5:176200000-176300000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:33,996 - INFO - Processing region chr5:176000000-176100000. (Only printing this message every 10 regions of size 100000)
# 2017-05-19 18:49:34,961 - INFO - Merging output VCF file(s) into final file result.vcf
# 2017-05-19 18:49:34,962 - INFO - Finished merging VCF file(s)
# 2017-05-19 18:49:34,962 - INFO - Finished variant calling

# %% [markdown]
# Let's look at the first 50 lines of the VCF file

# %%
head -n 50 result.vcf
